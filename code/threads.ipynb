# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/lauanton/Coding/convoy/convoy2weeks.csv")
# Out:
# /var/folders/m4/vndyt66d6q516qsz8ws65n24hlfnqv/T/ipykernel_93853/3141048338.py:1: DtypeWarning: Columns (19,20,21,56,58,59,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/Users/lauanton/Coding/convoy/convoy2weeks.csv")

# %%
data.head()
# Out:
#                     id      conversation_id  referenced_tweets.replied_to.id  \
# 0  1489750616326901762  1489750616326901762                              NaN
# 1  1489750615681085440  1489750615681085440                              NaN
# 2  1489750612921438210  1489464915119132672                     1.489465e+18
# 3  1489750610249355264  1489750610249355264                              NaN
# 4  1489750609062502400  1489734016286740485                     1.489734e+18
#
#    referenced_tweets.retweeted.id  referenced_tweets.quoted.id  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
#
#              author_id  in_reply_to_user_id  retweeted_user_id  \
# ...

# %%
conversation_ids = list(data.conversation_id)

# %%
conversation_ids[:6]
# Out:
# [1489750616326901762,
#  1489750615681085440,
#  1489464915119132672,
#  1489750610249355264,
#  1489734016286740485,
#  1489750596970323970]

# %%
queries = []

i = 0
base_query = 'twarc2 search --archive --start-time "2022-01-22T00:00:00" "'
current_query = base_query
while True:
    if i >= len(conversation_ids):
        print("Went thru all conversation ids")
        break
    next_id = conversation_ids[i]
    if len(current_query + "conversation_id:" + str(next_id)) > 1024:
        current_query = current_query[:len(current_query)-5]
        queries.append(current_query + '"') 
        current_query = base_query
    else:
        current_query += "conversation_id:" + str(conversation_ids[i]) + " OR "
        i += 1

print(queries[0:5])
# Out:
# Went thru all conversation ids
# ...
